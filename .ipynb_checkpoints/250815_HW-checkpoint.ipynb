# %% [markdown]
# # Homework 1
#
# Read the paper on volume: https://drive.google.com/drive/folders/1tdNz4ITkbVMU1GkZkyIwPWAmAd9H_fo0?usp=drive_link
#
# - Create a dataframe containing the data used in the paper.
# - Limit the country to usa and the timeframe from 2000 to 2005.
# - choose one ticker (NVDA) and plot each of the features across time
#
# Use this dataset:
# https://drive.google.com/file/d/1QYDnB2XaMs6gyPO0RnT23-0pTPsaBtWk/view?usp=drive_link
#
# Save in your github repository.
# Send the link to my email rbarit@ateneo.edu.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("prices.csv")

df["Date"] = pd.to_datetime(df["Date"], utc=True)

# %%
df["Date"] = df["Date"].dt.tz_localize(None)

# %%
df_filtered = df[
    (df["Ticker"] == "NVDA") &
    (df["Country"] == "usa") &
    (df["Date"].dt.year.between(2000, 2005))
]
df_filtered
# Out:
#                       Date      Open      High       Low     Close  \
# 257219 2005-12-30 05:00:00  2.833316  2.834082  2.783623  2.795091
# 257259 2005-12-29 05:00:00  2.912826  2.922001  2.837139  2.849371
# 257313 2005-12-28 05:00:00  2.887597  2.923530  2.869249  2.914356
# 257349 2005-12-27 05:00:00  2.866956  2.918944  2.857782  2.887598
# 257392 2005-12-23 05:00:00  2.855488  2.873836  2.836375  2.870013
# ...                    ...       ...       ...       ...       ...
# 309967 2000-01-07 05:00:00  0.783635  0.808720  0.771689  0.800359
# 309997 2000-01-06 05:00:00  0.842168  0.842168  0.754965  0.787218
# 310053 2000-01-05 05:00:00  0.845752  0.860087  0.830223  0.842169
# 310071 2000-01-04 05:00:00  0.879199  0.881589  0.826639  0.870838
# 310101 2000-01-03 05:00:00  0.903091  0.910259  0.843363  0.894729
#
#             Volume Brand_Name Ticker Industry_Tag Country  Dividends  \
# 257219  22960800.0     nvidia   NVDA   technology     usa        0.0
# 257259  31046400.0     nvidia   NVDA   technology     usa        0.0
# 257313  26442000.0     nvidia   NVDA   technology     usa        0.0
# 257349  36796800.0     nvidia   NVDA   technology     usa        0.0
# 257392  21453600.0     nvidia   NVDA   technology     usa        0.0
# ...            ...        ...    ...          ...     ...        ...
# 309967   7118400.0     nvidia   NVDA   technology     usa        0.0
# 309997  12048000.0     nvidia   NVDA   technology     usa        0.0
# 310053  18835200.0     nvidia   NVDA   technology     usa        0.0
# 310071  30048000.0     nvidia   NVDA   technology     usa        0.0
# 310101  30091200.0     nvidia   NVDA   technology     usa        0.0
#
#         Stock Splits  Capital Gains
# 257219           0.0            NaN
# 257259           0.0            NaN
# 257313           0.0            NaN
# 257349           0.0            NaN
# 257392           0.0            NaN
# ...              ...            ...
# 309967           0.0            NaN
# 309997           0.0            NaN
# 310053           0.0            NaN
# 310071           0.0            NaN
# 310101           0.0            NaN
#
# [1508 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(4, 1, figsize=(14, 12), sharex=True)

axes[0].plot(df_filtered["Date"], df_filtered["Open"], label="Open")
axes[0].plot(df_filtered["Date"], df_filtered["High"], label="High")
axes[0].plot(df_filtered["Date"], df_filtered["Low"], label="Low")
axes[0].plot(df_filtered["Date"], df_filtered["Close"], label="Close")
axes[0].set_ylabel("Price")
axes[0].set_title("NVDA OHLC Prices (2000–2005)")
axes[0].legend()
axes[0].grid(True)

axes[1].plot(df_filtered["Date"], df_filtered["Volume"], color="purple")
axes[1].set_ylabel("Volume")
axes[1].set_title("NVDA Volume (2000–2005)")
axes[1].grid(True)

axes[2].plot(df_filtered["Date"], df_filtered["Stock Splits"], color="red")
axes[2].set_ylabel("Stock Splits")
axes[2].set_title("NVDA Stock Splits (2000–2005)")
axes[2].grid(True)

axes[3].plot(df_filtered["Date"], df_filtered["Dividends"], color="blue")
axes[3].set_ylabel("Dividends")
axes[3].set_title("NVDA Dividends (2000–2005)")
axes[3].grid(True)

plt.xlabel("Date")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Homework 2
#
# Finish the Pandas course: https://www.kaggle.com/learn/pandas
# Screenshot the completion and send it to my email rbarit@ateneo.edu. Deadline: August 23, 2025 8am.
#
# ![image.png](attachment:34e5fd36-11fc-41ea-a095-f3e5c903bf98.png)

# %% [markdown]
# Highly encouraged to finish:
# - https://www.kaggle.com/learn/intro-to-programming
# - https://www.kaggle.com/learn/python
